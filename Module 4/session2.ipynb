# %% [markdown]
# # ADF Session - 2
# 1. First we will create a DataLake i.e. ADSL Gen2 (a storage account)
# 2. Image showing Azure Storage ACcount Creation:
# 3. storage account name: storageadf100
# 4. resource group: azure-data-factory-training
# 5. ![image.png](attachment:image.png)
# 6. Go to Advanced tab --> Click Data Lake Storage Gen2  --> mark the Check box
# 7. ![image.png](attachment:image-2.png)

# %% [markdown]
# **Create ADF**
# 1. Search for Data Factories
# 2. Create Data Factory
# 3. Name: adftraining100
# 4. Resource Group: azure-data-factory-training
#    1. ![image.png](attachment:image.png)

# %% [markdown]
# **Create a Linked service**
# 1. Name: ls_AzureSqlDatabase_customer360
# 2. ls  --> linked service --> naming convention
# 3. cutsomer360 is our database
# 4. Use SQL authentication
# 5. User name: swapnil
# 6. Password: Si....@1..4
# 7. Image below:
#    1. ![image.png](attachment:image.png)
# 8. If you are getting connection error:
#    1. check if your azure services are able to access SQL server
#    2. Go to SQL database (not azure sql server) --> click on overview --> (upper tabs) Set server firewall
#    3. Image:
#    4. ![image.png](attachment:image-2.png)
# 9.

# %% [markdown]
# **Create a Linked Service for ADSL Gen2 Datalake**
# 1. Name of linked service: ls_AzureDataLakeStorage_storageadf100
# 2. Choose the subscription
# 3. Choose the storage account i.e. storageadf100
# 4. Test the connection
# 5. Iamge: ![image.png](attachment:image.png)

# %% [markdown]
# **Step 1**
# - Using **Linked Services** connect both source & sink
#
# **Step 2**
# Create a dataset for both the source and sink
# - Why we need to create datasets?
# - Because we want to tell in what format the input data is
# - And we also want ot tell in what format in whcih format data should be saved
#
# **Step 3**
# - Create pipelines to copy/ingest/transform data
# - Create schedules/triggers for this pipeline
#
# **Step 4**
# - Monitor the pipeline
# - View Pipeline runs or trigger runs etc.

# %% [markdown]
# ### Create Datasets i.e. Step 2
# 1. Create a dataset for sql databse linked dataset
# 2. The start subscript is ds_
# 3. Name is: ds_azure_sql_customer_360
# 4. Image for this:
#    1. ![image.png](attachment:image.png)
# 5. Validate all settings by clicking on validate
# 6. Create a dataset for ADSL Gen2 datalake whcih is our sync (i.e. data dump)
# 7. Name is: ds_adslgen2_storageadf100
# 8. Image for this:
#    1. ![image.png](attachment:image-2.png)
# 9. Click on validate all
# 10. Click on Publish all

# %% [markdown]
# ### Create Pipeline i.e. Step 3
# 1. The start subscript is pl_
# 2. Name for this: pl_copy_from_sqldb_to_datalake
# 3. Keep all settings default
# 4. Image for this:
#    1. ![image.png](attachment:image.png)
# 5. Validate all
# 6. Click on debug to start debug to see output
#    1. Image fo rthis:
#    2. ![image.png](attachment:image-2.png)
# 7. Publish all
