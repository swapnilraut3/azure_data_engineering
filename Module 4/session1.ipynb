# %% [markdown]
# # Azure Data Factory (ADF)
#
# 1. Its a completely managed and serverless service
#    1. To ingest data (transfer)
#    2. Data Flow: Simple Transformations
#    3. Orchestration
#
# **Practical:**
# Copy data from SQL (RDBMS) server to datalake in a .csv file format.
# Source: RDBMS Table
# Sink: ADSL Gen2 i.e. Datalake
#
# Steps:
# 1. As we don't have SQL server setup... we need to setup one... create database and table inside it and create dummy data in that
# 2. We will copy this data using ADF
# 3. Go to https://portal.azure.com/#home
# 4. Search for SQL databases
# 5. Create a new SQL databases
# 6. Azure gives
#    1. Azure database for Mysql
#    2. Azure databse for postgresql
#    3. Azure database for MariaDB
#    4. Custom: Bring you own image & install it on VM and use it
# 7. Image for Creation of SQL server
#    1. Server name: swap-customer360-server
#    2. Use simple SQL authentication
#    3. Both Azure Active Directory & SQL basic auth is available but we will go with basic SQL auth
#    4. SQL username: swapnil
#    5. Pwd: Si****@1**4
#    6. ![image.png](attachment:image.png)
#    7. Image for database creation below: Have created a serverless, development only database while sumit has a production ready workload type
#    8. ![image.png](attachment:image-2.png)

# %% [markdown]
# **How to access SQL server**
# 1. Once deployment is complete --> go to resource
# 2. From left side open query editor
# 3. Login with  above username & passowrd
#    1. If you get login denied error due to firewall and public ip issue --> allow it
#    2. Go to overview --> Set server firewall --> allow public access to you own ip address
#    3. ![image.png](attachment:image.png)
# 4. Go to query editor and create a table and insert data into it
# 5. Below are queries to create table & insert data into it
# 6. Other ways to connect to SQL server on Azure is:
#    1. Azure Data Studio
#    2. SQL Server Management Studio

# %%
CREATE TABLE courses(
	course_id int NOT NULL,
	course_name VARCHAR(30) NOT NULL,
	course_duration_months INT NOT NULL,
	course_fee INT NOT NULL,
	PRIMARY KEY (course_id)
);
# Out:
# Running cells with 'c:\Users\pi\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/pi/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
INSERT INTO courses VALUES 
(1, 'big data', 6, 50000),
(2, 'web development', 3, 20000),
(3, 'data source', 6, 40000),
(4, 'devops', 1, 10000)
;
# Out:
# Running cells with 'c:\Users\pi\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/pi/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'
